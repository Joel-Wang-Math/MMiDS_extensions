# %% [markdown]
# <a href="https://colab.research.google.com/github/Joel-Wang-Math/MMiDS_extensions/blob/main/Visualization_and_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from numpy import linalg as LA
import matplotlib.pyplot as plt
import pandas as pd
import networkx as nx
import torch
import mmids

# %%
data = pd.read_csv("penguins-measurements.csv")
data.head()
# Out:
#    bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# 0            39.1           18.7              181.0       3750.0
# 1            39.5           17.4              186.0       3800.0
# 2            40.3           18.0              195.0       3250.0
# 3             NaN            NaN                NaN          NaN
# 4            36.7           19.3              193.0       3450.0

# %%
#data = data.dropna() #This kind of pre-processing is fundamental in data science
data.head()
# Out:
#    bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# 0            39.1           18.7              181.0       3750.0
# 1            39.5           17.4              186.0       3800.0
# 2            40.3           18.0              195.0       3250.0
# 3             NaN            NaN                NaN          NaN
# 4            36.7           19.3              193.0       3450.0

# %%
# Alternative ways to deal with missing values in a dataset

#data.fillna(data.mean(), inplace=True) #Fill with the column’s mean/median/mode
#data.fillna(method='ffill',inplace=True)#Forward fill (use previous value)
data.interpolate(inplace=True)#Uses trends in the data to guess the missing values
data.head()
# Out:
#    bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# 0            39.1          18.70              181.0       3750.0
# 1            39.5          17.40              186.0       3800.0
# 2            40.3          18.00              195.0       3250.0
# 3            38.5          18.65              194.0       3350.0
# 4            36.7          19.30              193.0       3450.0

# %%
data.shape# it is an attribute not a function with parenthese ()
# Out:
# (344, 4)

# %%
X = data.to_numpy() #.to_numpy() is like a bridge between pandas and NumPy. It converts a pandas DataFrame into a NumPy array
print(X)# you can see that a DataFrame is changed into an array
# Out:
# [[  39.1   18.7  181.  3750. ]
#  [  39.5   17.4  186.  3800. ]
#  [  40.3   18.   195.  3250. ]
#  ...
#  [  50.4   15.7  222.  5750. ]
#  [  45.2   14.8  212.  5200. ]
#  [  49.9   16.1  213.  5400. ]]

# %%
plt.scatter(X[:,1],X[:,2],s=500,c='k') #every time you use string as input, you need parenthese (); s is the size of point
plt.xlabel('bill_depth_mm'),plt.ylabel('flipper_length_mm')#by using comma, you're technically creating a tuple (a,b)
plt.show()

# %%
import seaborn as sns #seaborn is a high-level visualization package in Python
sns.pairplot(data,height = 1.314) #height is the size of plot
plt.show()
